# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np

# %%
#df_s11 = df_s11.dropna(subset=["valence_rating"])

# %%
df_s20_1 = pd.read_parquet("../data/03_primary/pupil_positions/2023_01_05_10-42 s20_pic_000_p.parquet")
df_s20_2 = pd.read_parquet("../data/03_primary/pupil_positions/2023_01_05_10-33 s20_pic_000_p.parquet")
df_s20_3 = pd.read_parquet("../data/03_primary/pupil_positions/2023_01_05_10-50 s20_pic_000_p.parquet")

# %%
df_s40_1 = pd.read_parquet("../data/03_primary/pupil_positions/2023_01_12_11-26 s40_pic_000_p.parquet")
df_s40_2 = pd.read_parquet("../data/03_primary/pupil_positions/2023_01_12_11-34 s40_pic_000_p.parquet")
df_s40_3 = pd.read_parquet("../data/03_primary/pupil_positions/2023_01_12_11-42 s40_pic_000_p.parquet")

# %%
# df_x = pd.concat([df_s20_1, df_s20_2, df_s20_3])

# %%
df_x = pd.concat([df_s40_1, df_s40_2, df_s40_3])

# %%
df_x["arousal_rating"].max()
# Out:
# 8.0

# %%
sns.histplot(data=df_x, x="confidence")
# Out:
# <Axes: xlabel='confidence', ylabel='Count'>

# %%
df_x[df_x["confidence"] > 0.7].groupby(["valence_rating"]).agg(["var"]).reset_index()
# Out:
# C:\Users\dbugajny\AppData\Local\Temp\ipykernel_22876\2836703249.py:1: FutureWarning: ['method', 'person_id'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_x[df_x["confidence"] > 0.7].groupby(["valence_rating"]).agg(["var"]).reset_index()
#   valence_rating      timestamp    eye_id confidence norm_pos_x norm_pos_y  \
#                             var       var        var        var        var
# 0            1.0   44469.884977  0.249119   0.007523   0.002490   0.003448
# 1            2.0   86475.207404  0.249820   0.007260   0.001737   0.002785
# 2            3.0  199783.249721  0.249370   0.008223   0.002508   0.002643
# 3            4.0  138803.938356  0.249678   0.007712   0.002400   0.002969
# 4            5.0  152651.217246  0.249555   0.007350   0.002863   0.002283
# 5            6.0  153668.541203  0.250007   0.007020   0.002757   0.002235
# ...

# %%
df_x.groupby(["valence_rating"]).mean(numeric_only=True)
# Out:
#                  timestamp    eye_id  confidence  norm_pos_x  norm_pos_y  \
# valence_rating
# 1.0             566.071214  0.524237    0.800625    0.458768    0.514782
# 2.0             344.365493  0.513761    0.847679    0.454687    0.523246
# 3.0             500.041032  0.511443    0.825654    0.447293    0.523863
# 4.0             408.284992  0.517039    0.834166    0.444033    0.526223
# 5.0             327.902557  0.538553    0.855439    0.448724    0.528658
# 6.0             477.079409  0.521760    0.821380    0.443486    0.527506
# 7.0             402.691047  0.519861    0.831820    0.449922    0.527389
# 8.0             482.631077  0.491816    0.785746    0.453714    0.523801
# 9.0             327.776787  0.578096    0.805830    0.440475    0.540604
#
#                  diameter      image_id  arousal_rating  valence_norm  \
# valence_rating
# 1.0             17.107828  43212.000000        9.000000      2.000000
# ...

# %%
df_x.groupby(["arousal_rating"]).variance(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df_x.groupby(["arousal_rating"]).variance(numeric_only=True)
#
# File ~\PycharmProjects\Emotion-Recognition\venv\lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'variance'

# %%
df_x = df_x.dropna(subset=["valence_rating"])
df_x = df_x[df_x["diameter"] > 5]
df_x = df_x[df_x["diameter"] < 40]

# %%
plt.figure(figsize=(20, 5))
sns.scatterplot(data=df_x.iloc[:20000], x="timestamp", y="diameter", hue="valence_rating", palette="colorblind")
plt.show()
